# %% [markdown]
# <a href="https://colab.research.google.com/github/tommystarrrrrrr/2025_Kecerdasan-Buatan/blob/main/jobsheet3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pengukuran Statistik Deskriptif

# %% [markdown]
# ## 1.	Central Tendency

# %% [markdown]
# #### a. Mendapatkan Nilai Mean

# %%
import numpy as np

score = [90, 80, 70, 65, 110, 80, 83, 67, 94]
x = np.mean(score)
print("Mean:", x)
# Out:
# Mean: 82.11111111111111

# %% [markdown]
# #### b.	Mendapatkan Nilai Median

# %%
import numpy as np

score = [90, 80, 70, 65, 110, 80, 83, 67, 94]
x = np.median(score)
print("Median:", x)
# Out:
# Median: 80.0

# %% [markdown]
# #### c.	Mendapatkan Nilai Modus / Mode

# %%
from scipy import stats

score = [90, 80, 70, 65, 110, 80, 83, 67, 94]

x = stats.mode(score, keepdims=True)
print("Modus:", x.mode[0])
print("Frekuensi:", x.count[0])
# Out:
# Modus: 80
# Frekuensi: 2

# %% [markdown]
# ## 2.	Spread

# %% [markdown]
# #### a.	Mendapatkan Nilai Range

# %%
import numpy as np

data = [2, 3, 7, 8, 9, 12, 15, 20, 50, 42]
minimum = np.min(data)
maximum = np.max(data)
x = maximum - minimum
print("Range:", x)
# Out:
# Range: 48

# %% [markdown]
# #### b.	Mendapatkan Nilai Percentile

# %%
import numpy as np

data = [90, 80, 70, 65, 110, 80, 83, 67, 94]
x = np.percentile(data, 90)
print("Percentile ke-90:", x)
# Out:
# Percentile ke-90: 97.2

# %% [markdown]
# #### c.	Mendapatkan Nilai Quartile dan Interquartile Range

# %%
import numpy as np

data = [3, 4, 4, 5, 5, 6, 6, 7, 8, 8, 9, 10]
Q1 = np.median(data[:int(len(data)/2)])
Q3 = np.median(data[int(len(data)/2):])
IQR = Q3 - Q1
print("Q1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)
# Out:
# Q1: 4.5
# Q3: 8.0
# IQR: 3.5

# %% [markdown]
# #### d.	Mendapatkan Nilai Variance dan Standart Deviation

# %%
import numpy as np

data = [86, 87, 88, 86, 87, 85, 86]
mean = np.mean(data)
var = np.var(data)
std = np.std(data)
print("Mean:", mean)
print("Variance:", var)
print("Standar Deviasi:", std)
# Out:
# Mean: 86.42857142857143
# Variance: 0.8163265306122449
# Standar Deviasi: 0.9035079029052513

# %% [markdown]
# # Tugas Praktikum

# %% [markdown]
# ### 1. Menentukan Modus dari Data Hasil Pelemparan Dadu

# %%
from scipy import stats

dadu = [1, 2, 3, 4, 5, 5, 6, 2, 3, 4, 5, 6, 6, 4, 3, 2, 1, 4, 3, 5, 6, 6, 5, 4, 5]

x = stats.mode(dadu, keepdims=True)
print("Modus dari data dadu adalah:", x.mode[0])
# Out:
# Modus dari data dadu adalah: 5

# %% [markdown]
# ### 2. Menentukan Persentil 25 dan 75 dari Deret Data

# %%
import numpy as np

# Data deret
data = [9, 10, 11, 6, 8, 7, 7, 5, 4, 5]

# Mengurutkan data (opsional, hanya untuk melihat)
data_sorted = sorted(data)
print("Data urut:", data_sorted)

# Menghitung persentil ke-25 dan ke-75
q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)

print("Persentil ke-25 (Q1):", q1)
print("Persentil ke-75 (Q3):", q3)
# Out:
# Data urut: [4, 5, 5, 6, 7, 7, 8, 9, 10, 11]
# Persentil ke-25 (Q1): 5.25
# Persentil ke-75 (Q3): 8.75

# %% [markdown]
# ### 3. Pengolahan Data Nilai Hasil Ujian

# %% [markdown]
# #### a. Data Diurutkan dari Terkecil ke Terbesar

# %%
import numpy as np

# Data nilai ujian
nilai = [50, 54, 62, 50, 52, 59, 61, 63, 65, 10, 53, 63, 65, 50, 59,
         62, 50, 51, 57, 60, 63, 65, 65, 53, 99]

# Menghitung Q1 dan Q3
Q1 = np.percentile(nilai, 25)
Q3 = np.percentile(nilai, 75)

# Interquartile Range (IQR)
IQR = Q3 - Q1

# Lower Bound dan Upper Bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Output
print("a. Lower Bound:", lower_bound)
print("   Upper Bound:", upper_bound)
# Out:
# a. Lower Bound: 35.5
#    Upper Bound: 79.5

# %% [markdown]
# #### b. Nilai First Quartile (Q1), Third Quartile (Q3), dan IQR

# %%
import numpy as np

# Data nilai ujian
nilai = [50, 54, 62, 50, 52, 59, 61, 63, 65, 10, 53, 63, 65, 50, 59,
         62, 50, 51, 57, 60, 63, 65, 65, 53, 99]

# Menghitung Q1 dan Q3
Q1 = np.percentile(nilai, 25)
Q3 = np.percentile(nilai, 75)
IQR = Q3 - Q1

# Hitung batas bawah dan atas
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Cari nilai yang di luar batas (outlier)
outlier = [x for x in nilai if x < lower_bound or x > upper_bound]

# Output
print("b. Outlier nilai ujian:", outlier)
# Out:
# b. Outlier nilai ujian: [10, 99]

# %% [markdown]
# #### c. Nilai Upper Bound dan Lower Bound

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)
# Out:
# Lower Bound: -0.75
# Upper Bound: 13.25

# %% [markdown]
# #### d. Nilai Ujian yang Menjadi Outlier

# %%
outlier = [x for x in nilai_sorted if x < lower_bound or x > upper_bound]
print("Outlier:", outlier)
# Out:
# Outlier: [10, 99]

# %% [markdown]
# ### 4. Menghitung Standar Deviasi dari Data Berat Badan Mahasiswa Informatika IK-2E

# %%
import numpy as np

# Interval dan frekuensi
interval = [(41, 45), (46, 50), (50, 55), (56, 60), (61, 65), (66, 70)]
frekuensi = [2, 3, 6, 4, 5, 2]

# Titik tengah
tengah = [(a + b) / 2 for a, b in interval]

# Rata-rata tertimbang
mean = np.average(tengah, weights=frekuensi)

# Variansi dan standar deviasi
var = np.average((np.array(tengah) - mean) ** 2, weights=frekuensi)
std = np.sqrt(var)

print("Standar deviasi berat badan:", round(std, 2))
# Out:
# Standar deviasi berat badan: 7.24
