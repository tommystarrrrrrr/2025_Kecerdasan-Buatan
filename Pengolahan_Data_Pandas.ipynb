# %% [markdown]
# <a href="https://colab.research.google.com/github/tommystarrrrrrr/2025_Kecerdasan-Buatan/blob/main/Pengolahan_Data_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # JOBSHEET 4: Pengolahan Data Menggunakan Pandas

# %% [markdown]
# ## 1. membaca berbagai format file menggunakan pandass

# %% [markdown]
# ### CSV

# %%
import pandas as pd

df = pd.read_csv('./data CSV.csv')
print(df.to_string())
df
pd.options.display.max_rows
pd.options.display.max_rows = 9999
df = pd.read_csv('./data CSV.csv')
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %% [markdown]
# ### JSON

# %%
import pandas as pd

df = pd.read_json('./data file JSON.json')
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %% [markdown]
# ### Menggunakan Parameter pada Pandas Read

# %%
df = pd.read_csv('./data CSV.csv', sep=',', header=0)
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %% [markdown]
# ### Membaca costum data

# %%
data = {
  "Duration": {
    "0":60, "1":60, "2":60, "3":45
  },
  "Pulse": {
    "0":110, "1":117, "2":103, "3":109
  },
  "Maxpulse": {
    "0":130, "1":145, "2":135, "3":175
  },
  "Calories": {
    "0":409, "1":479, "2":340, "3":282
  }
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282

# %% [markdown]
# ## 2. Membuat dan Mengakses Elemen Series

# %% [markdown]
# ### Membuat Series dari sebuah List Python

# %%
import pandas as pd

li = [1, 7, 2]
se = pd.Series(li)

print(se)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %% [markdown]
# ### Mengakses Elemen pada Series

# %%
li = [1, 7, 2]
se = pd.Series(li)

print(se[0])
# Out:
# 1

# %% [markdown]
# ### Memberi Label pada Series

# %%
li = [1, 7, 2]
se = pd.Series(li, index = ['x', 'y', 'z'])

print(se['x'])
# Out:
# 1

# %% [markdown]
# ### Membuat Series dari Dictionary

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}
se = pd.Series(calories)

print(se)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %% [markdown]
# ## 3. membuat DataFrame

# %% [markdown]
# ### membuat dataframe

# %%
import pandas as pd

df = pd.DataFrame(data= {
  "Nama" : ["Ali","Joko","Adi"],
  "Umur": [12, 13, 15],
  "Kelas": [6, 7, 8]
})

df.columns
df.columns.values[0] = "Nama Singkat"
df
# Out:
#   Nama Singkat  Umur  Kelas
# 0          Ali    12      6
# 1         Joko    13      7
# 2          Adi    15      8

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data)
df
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# ### Mengakses Elemen pada DataFrame

# %%
df.iloc[0:2, [0,1]]
df.iloc[0:2, 0:2]
df.iloc[:, 0:2]
df.loc[0:2, :'calories']
df.loc[0:2, ['calories', 'duration']]
df['calories']
df['calories'][0]
df[['calories']]
df[['calories']].loc[[0, 1]]
# Out:
#    calories
# 0       420
# 1       380

# %% [markdown]
# ### memberi nama pada indeks

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ['day1', 'day2', 'day3'])
print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %% [markdown]
# ### Melihat dataframe

# %%
df = pd.read_csv('./data CSV.csv')
print(df)

df
df.head()
df.tail()
df.head(10)
df.shape
df.dtypes
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %% [markdown]
# ### membaca informasi pada dataframe

# %%
df.info()
df.describe()
df['Calories'].mean(), df['Calories'].median(), df['Calories'].mode()[0]
df.corr()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000

# %% [markdown]
# # Tugas Praktikum

# %% [markdown]
# 1.

# %%
# Import library
import pandas as pd

# Load dataset
df = pd.read_csv('/content/epl-goalScorer(20-21).csv')

# TUGAS 1
print("Tugas 1 - DataFrame berhasil dibuat!")
print(df.head())
# Out:
# Tugas 1 - DataFrame berhasil dibuat!
#    Unnamed: 0    id      player_name  games  time  goals         xG  assists  \
# 0           0   647       Harry Kane     35  3097     23  22.174859       14
# 1           1  1250    Mohamed Salah     37  3085     22  20.250847        5
# 2           2  1228  Bruno Fernandes     37  3117     18  16.019454       12
# 3           3   453    Son Heung-Min     37  3139     17  11.023287       10
# 4           4   822  Patrick Bamford     38  3085     17  18.401863        7
#
#           xA  shots  key_passes  yellow_cards  red_cards position  \
# 0   7.577094    138          49             1          0        F
# 1   6.528526    126          55             0          0    F M S
# 2  11.474996    121          95             6          0      M S
# 3   9.512992     68          75             0          0    F M S
# 4   3.782247    107          30             3          0      F S
#
#           team_title  npg       npxG    xGChain  xGBuildup
# ...

# %% [markdown]
# 2.

# %%
# TUGAS 2: Ambil 5 data pertama
print("\nTugas 2 - 5 Data Pertama:")
print(df.head(5))
# Out:
# Tugas 2 - 5 Data Pertama:
#    Unnamed: 0    id      player_name  games  time  goals         xG  assists  \
# 0           0   647       Harry Kane     35  3097     23  22.174859       14
# 1           1  1250    Mohamed Salah     37  3085     22  20.250847        5
# 2           2  1228  Bruno Fernandes     37  3117     18  16.019454       12
# 3           3   453    Son Heung-Min     37  3139     17  11.023287       10
# 4           4   822  Patrick Bamford     38  3085     17  18.401863        7
#
#           xA  shots  key_passes  yellow_cards  red_cards position  \
# 0   7.577094    138          49             1          0        F
# 1   6.528526    126          55             0          0    F M S
# 2  11.474996    121          95             6          0      M S
# 3   9.512992     68          75             0          0    F M S
# 4   3.782247    107          30             3          0      F S
#
#           team_title  npg       npxG    xGChain  xGBuildup
# ...

# %% [markdown]
# 3.

# %%
# TUGAS 3: Tampilkan jumlah baris dan kolom
print("\nTugas 3 - Jumlah Baris dan Kolom:")
print(f"Jumlah baris: {df.shape[0]}")
print(f"Jumlah kolom: {df.shape[1]}")
# Out:
# Tugas 3 - Jumlah Baris dan Kolom:
# Jumlah baris: 522
# Jumlah kolom: 19

# %% [markdown]
# 4.

# %%
# TUGAS 4: Tampilkan tipe data dari masing-masing kolom
print("\nTugas 4 - Tipe Data Kolom:")
print(df.dtypes)
# Out:
# Tugas 4 - Tipe Data Kolom:
# Unnamed: 0        int64
# id                int64
# player_name      object
# games             int64
# time              int64
# goals             int64
# xG              float64
# assists           int64
# xA              float64
# shots             int64
# key_passes        int64
# yellow_cards      int64
# red_cards         int64
# position         object
# team_title       object
# npg               int64
# npxG            float64
# xGChain         float64
# xGBuildup       float64
# dtype: object

# %% [markdown]
# 5.

# %%
print("--- Jumlah goal setiap pemain ---")
print(df[['player_name', 'goals']])
# Out:
# --- Jumlah goal setiap pemain ---
#                    player_name  goals
# 0                   Harry Kane     23
# 1                Mohamed Salah     22
# 2              Bruno Fernandes     18
# 3                Son Heung-Min     17
# 4              Patrick Bamford     17
# 5        Dominic Calvert-Lewin     16
# 6                  Jamie Vardy     15
# 7                Ollie Watkins     14
# 8               Ilkay Gündogan     13
# 9          Alexandre Lacazette     13
# 10               Callum Wilson     12
# 11           Kelechi Iheanacho     12
# 12                  Danny Ings     12
# 13                  Chris Wood     12
# 14               Wilfried Zaha     11
# 15             Marcus Rashford     11
# 16                  Sadio Mané     11
# 17                 Gareth Bale     11
# 18             Matheus Pereira     11
# 19   Pierre-Emerick Aubameyang     10
# 20             Michail Antonio     10
# 21           Christian Benteke     10
# 22             Raheem Sterling     10
# ...

# %% [markdown]
# 6.

# %%
selected_columns = df[['player_name', 'goals', 'position', 'team_title', 'yellow_cards']]
print(selected_columns.to_string(index=False))
# Out:
#               player_name  goals position                    team_title  yellow_cards
#                Harry Kane     23        F                     Tottenham             1
#             Mohamed Salah     22    F M S                     Liverpool             0
#           Bruno Fernandes     18      M S             Manchester United             6
#             Son Heung-Min     17    F M S                     Tottenham             0
#           Patrick Bamford     17      F S                         Leeds             3
#     Dominic Calvert-Lewin     16      F S                       Everton             3
#               Jamie Vardy     15      F S                     Leicester             1
#             Ollie Watkins     14        F                   Aston Villa             2
#            Ilkay Gündogan     13      M S               Manchester City             1
#       Alexandre Lacazette     13    F M S                       Arsenal             3
# ...

# %% [markdown]
# 7.

# %%
print("Pemain Liverpool:")
print(df[df['team_title'] == 'Liverpool'])
# Out:
# Pemain Liverpool:
#      Unnamed: 0    id              player_name  games  time  goals         xG  \
# 1             1  1250            Mohamed Salah     37  3085     22  20.250847
# 16           16   838               Sadio Mané     35  2805     11  14.828548
# 26           26   482          Roberto Firmino     36  2882      9  12.860213
# 30           30  6854               Diogo Jota     19  1114      9   7.057721
# 116         116   771      Georginio Wijnaldum     38  2961      2   2.817427
# 130         130  1791   Trent Alexander-Arnold     36  3040      2   2.593060
# 161         161   229         Thiago Alcántara     24  1865      1   1.211306
# 162         162   332               Joel Matip     10   701      1   0.784475
# 172         172   605         Jordan Henderson     21  1710      1   1.135798
# 187         187   833          Virgil van Dijk      5   370      1   0.553383
# 192         192   966  Alex Oxlade-Chamberlain     13   238      1   0.300651
# ...

# %% [markdown]
# 8.

# %%
print("Pemain Arsenal:")
print(df[df['team_title'] == 'Arsenal'])
# Out:
# Pemain Arsenal:
#      Unnamed: 0    id                player_name  games  time  goals  \
# 9             9  3277        Alexandre Lacazette     30  1928     13
# 19           19   318  Pierre-Emerick Aubameyang     28  2254     10
# 36           36  5656               Nicolas Pepe     28  1512      8
# 65           65  7322                Bukayo Saka     31  2561      5
# 140         140  5613                    Gabriel     22  1904      2
# 146         146  6482              Eddie Nketiah     17   405      2
# 149         149  7230           Emile Smith-Rowe     19  1382      2
# 152         152  7752         Gabriel Martinelli     13   577      2
# 160         160   204               Granit Xhaka     30  2447      1
# 164         164   492            Héctor Bellerín     25  2098      1
# 165         165   496             Mohamed Elneny     23  1540      1
# 180         180   700                    Willian     25  1413      1
# ...

# %% [markdown]
# 9.

# %%
print("10 pemain dengan kartu kuning terbanyak:")
print(df[['player_name', 'yellow_cards']].sort_values(by='yellow_cards', ascending=False).head(10))
# Out:
# 10 pemain dengan kartu kuning terbanyak:
#                player_name  yellow_cards
# 106            John McGinn            12
# 157        Conor Gallagher            11
# 125          Harry Maguire            11
# 259        Kalvin Phillips            10
# 110  Pierre-Emile Højbjerg             9
# 216       Luka Milivojevic             8
# 397           Isaac Hayden             8
# 218          Yves Bissouma             8
# 448         John Lundstram             8
# 399           Douglas Luiz             8

# %% [markdown]
# 10.

# %%
print("10 pemain dengan kartu merah terbanyak:")
print(df[['player_name', 'red_cards']].sort_values(by='red_cards', ascending=False).head(10))
# Out:
# 10 pemain dengan kartu merah terbanyak:
#              player_name  red_cards
# 61            Lewis Dunk          2
# 488         Matthew Cash          1
# 493     Antonee Robinson          1
# 21     Christian Benteke          1
# 18       Matheus Pereira          1
# 476  Alexandre Jankewitz          1
# 25          Tomas Soucek          1
# 443            John Egan          1
# 433            Ben White          1
# 421         Matt Doherty          1
